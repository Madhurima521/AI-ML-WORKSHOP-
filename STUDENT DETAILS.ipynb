# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlp

# %%
import io
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-25a2cdbb-2e33-4310-9bae-3f2b62149ffe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25a2cdbb-2e33-4310-9bae-3f2b62149ffe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datafile=pd.read_csv("studentdetails2.csv")

# %%
datafile.head()
# Out:
#    ROLLNO      NAME       ADDRESS DEPARTMENT
# 0     1.0     Madhu       Nandyal        CSE
# 1     2.0    Mahesh     Hyderabad      CIVIL
# 2     3.0    Prabas    Vijayawada       MECH
# 3     4.0    Sruthi        Guntur        ECE
# 4     5.0  Rashmika  Srikakularam        EEE

# %%
datafile.drop
# Out:
# <bound method DataFrame.drop of     ROLLNO         NAME        ADDRESS DEPARTMENT
# 0      1.0        Madhu        Nandyal        CSE
# 1      2.0       Mahesh      Hyderabad      CIVIL
# 2      3.0       Prabas     Vijayawada       MECH
# 3      4.0       Sruthi         Guntur        ECE
# 4      5.0     Rashmika   Srikakularam        EEE
# 5      6.0     Samantha  Vijayanagaram        CSE
# 6      7.0        Arjun          Vizag      CIVIL
# 7      8.0        Vijay       Godavari       MECH
# 8      9.0      Sweetie        Nellore        ECE
# 9     10.0         Ajay   Ananthapuram        EEE
# 10    11.0       Suresh         Kadapa        CSE
# 11    12.0        Madhu        Chitoor      CIVIL
# 12    13.0        Pavan   Ananthapuram       MECH
# 13    14.0        Sudha      Hyderabad        ECE
# 14     NaN  Raghavendra  Vijayanagaram        EEE
# 15    16.0        Surya          Vizag        CSE
# 16    17.0        Bommi      Hyderabad      CIVIL
# ...

# %%
datafile.dropna()
# Out:
#     ROLLNO      NAME        ADDRESS DEPARTMENT
# 0      1.0     Madhu        Nandyal        CSE
# 1      2.0    Mahesh      Hyderabad      CIVIL
# 2      3.0    Prabas     Vijayawada       MECH
# 3      4.0    Sruthi         Guntur        ECE
# 4      5.0  Rashmika   Srikakularam        EEE
# 5      6.0  Samantha  Vijayanagaram        CSE
# 6      7.0     Arjun          Vizag      CIVIL
# 7      8.0     Vijay       Godavari       MECH
# 8      9.0   Sweetie        Nellore        ECE
# 9     10.0      Ajay   Ananthapuram        EEE
# 10    11.0    Suresh         Kadapa        CSE
# 11    12.0     Madhu        Chitoor      CIVIL
# 12    13.0     Pavan   Ananthapuram       MECH
# 13    14.0     Sudha      Hyderabad        ECE
# 15    16.0     Surya          Vizag        CSE
# 16    17.0     Bommi      Hyderabad      CIVIL
# 18    19.0     Sneha     Vijayawada        ECE
# 19    20.0     Sanju         Guntur        EEE

# %%
datafile.fillna(0)
# Out:
#     ROLLNO         NAME        ADDRESS DEPARTMENT
# 0      1.0        Madhu        Nandyal        CSE
# 1      2.0       Mahesh      Hyderabad      CIVIL
# 2      3.0       Prabas     Vijayawada       MECH
# 3      4.0       Sruthi         Guntur        ECE
# 4      5.0     Rashmika   Srikakularam        EEE
# 5      6.0     Samantha  Vijayanagaram        CSE
# 6      7.0        Arjun          Vizag      CIVIL
# 7      8.0        Vijay       Godavari       MECH
# 8      9.0      Sweetie        Nellore        ECE
# 9     10.0         Ajay   Ananthapuram        EEE
# 10    11.0       Suresh         Kadapa        CSE
# 11    12.0        Madhu        Chitoor      CIVIL
# 12    13.0        Pavan   Ananthapuram       MECH
# 13    14.0        Sudha      Hyderabad        ECE
# 14     0.0  Raghavendra  Vijayanagaram        EEE
# 15    16.0        Surya          Vizag        CSE
# 16    17.0        Bommi      Hyderabad      CIVIL
# 17     0.0         Maha     Vijayawada       MECH
# ...

# %%
datafile.fillna(0)
datafile["ROLLNO"].mean()
# Out:
# 9.833333333333334

# %%
datafile.fillna(0)
datafile["ROLLNO"].median()
# Out:
# 9.5

# %%
datafile.fillna(0)
datafile["ROLLNO"].mode()
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    16.0
# 15    17.0
# 16    19.0
# 17    20.0
# dtype: float64
